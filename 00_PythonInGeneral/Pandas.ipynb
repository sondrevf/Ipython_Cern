# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Introduction to Pandas

# %%
# import a data file on immigration to Canada

# !pip install xlrd
df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                       skipfooter=2)
print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
# read first 5 rows
df_can.head(2)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
#
#    DEV             DevName  1980  ...  2004  2005  2006  2007  2008  2009  \
# 0  902  Developing regions    16  ...  2978  3436  3009  2652  2111  1746
# 1  901   Developed regions     1  ...  1450  1223   856   702   560   716
#
#    2010  2011  2012  2013
# 0  1758  2203  2635  2004
# 1   561   539   620   603
#
# [2 rows x 43 columns]

# %%
#or last 5
df_can.tail(2)
# Out:
#            Type    Coverage    OdName  AREA AreaName  REG         RegName  \
# 193  Immigrants  Foreigners    Zambia   903   Africa  910  Eastern Africa
# 194  Immigrants  Foreigners  Zimbabwe   903   Africa  910  Eastern Africa
#
#      DEV             DevName  1980  ...  2004  2005  2006  2007  2008  2009  \
# 193  902  Developing regions    11  ...    56    91    77    71    64    60
# 194  902  Developing regions    72  ...  1450   615   454   663   611   508
#
#      2010  2011  2012  2013
# 193   102    69    46    59
# 194   494   434   437   407
#
# [2 rows x 43 columns]

# %%
# Dataframe Information
print(df_can.info())
print(df_can.columns.values)
print(df_can.index.values)
print(df_can.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
# Type        195 non-null object
# Coverage    195 non-null object
# OdName      195 non-null object
# AREA        195 non-null int64
# AreaName    195 non-null object
# REG         195 non-null int64
# RegName     195 non-null object
# DEV         195 non-null int64
# DevName     195 non-null object
# 1980        195 non-null int64
# 1981        195 non-null int64
# 1982        195 non-null int64
# 1983        195 non-null int64
# 1984        195 non-null int64
# 1985        195 non-null int64
# 1986        195 non-null int64
# 1987        195 non-null int64
# 1988        195 non-null int64
# 1989        195 non-null int64
# 1990        195 non-null int64
# 1991        195 non-null int64
# 1992        195 non-null int64
# 1993        195 non-null int64
# 1994        195 non-null int64
# 1995        195 non-null int64
# 1996        195 non-null int64
# ...

# %%
# Dataframe manipulation
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can['Total'] = df_can.sum(axis=1,numeric_only=True)


df_can.head(1)
# Out:
#        Country Continent         Region             DevName  1980  1981  1982  \
# 0  Afghanistan      Asia  Southern Asia  Developing regions    16    39    39
#
#    1983  1984  1985  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0    47    71   340  ...  3436  3009  2652  2111  1746  1758  2203  2635
#
#    2013  Total
# 0  2004  58639
#
# [1 rows x 39 columns]

# %%
# To set name of the index
df_can.set_index('Country', inplace=True)

# to remove the name of the index
# df_can.index.name = None


df_can.head(1)
# Out:
#             Continent         Region             DevName  1980  1981  1982  \
# Country
# Afghanistan      Asia  Southern Asia  Developing regions    16    39    39
#
#              1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  \
# Country                              ...
# Afghanistan    47    71   340   496  ...  3436  3009  2652  2111  1746  1758
#
#              2011  2012  2013  Total
# Country
# Afghanistan  2203  2635  2004  58639
#
# [1 rows x 38 columns]

# %%
# Check for problems
df_can.isnull().sum() ;

# %%
# Quick summary
df_can.describe()
# Out:
#                1980          1981          1982          1983          1984  \
# count    195.000000    195.000000    195.000000    195.000000    195.000000
# mean     508.394872    566.989744    534.723077    387.435897    376.497436
# std     1949.588546   2152.643752   1866.997511   1204.333597   1198.246371
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%       13.000000     10.000000     11.000000     12.000000     13.000000
# 75%      251.500000    295.500000    275.000000    173.000000    181.000000
# max    22045.000000  24796.000000  20620.000000  10015.000000  10170.000000
#
#               1985         1986          1987          1988          1989  \
# count   195.000000   195.000000    195.000000    195.000000    195.000000
# mean    358.861538   441.271795    691.133333    714.389744    843.241026
# ...

# %% [markdown]
# ## Intermediate

# %%
# To get a column
df_can.Continent            # returns series
df_can['Continent']         # returns series 
df_can[['Continent',1980]]  # returns dataframe
None

# %%
# To get a row
df_can.loc['Albania']   # by label 
df_can.iloc[0]          # by index
# Out:
# Continent                  Asia
# Region            Southern Asia
# DevName      Developing regions
# 1980                         16
# 1981                         39
# 1982                         39
# 1983                         47
# 1984                         71
# 1985                        340
# 1986                        496
# 1987                        741
# 1988                        828
# 1989                       1076
# 1990                       1028
# 1991                       1378
# 1992                       1170
# 1993                        713
# 1994                        858
# 1995                       1537
# 1996                       2212
# 1997                       2555
# 1998                       1999
# 1999                       2395
# 2000                       3326
# 2001                       4067
# 2002                       3697
# 2003                       3479
# 2004                       2978
# 2005                       3436
# ...

# %%
# Print all about India
print(df_can.loc['India'])
# Print year 1980 for India
print(df_can.loc['India',1980])
# Print year 1980 to 1990 for India
print(df_can.loc['India',np.arange(1980,1991)])
# Out:
# Continent                  Asia
# Region            Southern Asia
# DevName      Developing regions
# 1980                       8880
# 1981                       8670
# 1982                       8147
# 1983                       7338
# 1984                       5704
# 1985                       4211
# 1986                       7150
# 1987                      10189
# 1988                      11522
# 1989                      10343
# 1990                      12041
# 1991                      13734
# 1992                      13673
# 1993                      21496
# 1994                      18620
# 1995                      18489
# 1996                      23859
# 1997                      22268
# 1998                      17241
# 1999                      18974
# 2000                      28572
# 2001                      31223
# 2002                      31889
# 2003                      27155
# 2004                      28235
# 2005                      36210
# ...

# %%
# Filter based on a criteria
condition = (df_can['Continent'] == 'Oceania') & (df_can['Region']=='Polynesia')
df_can[condition]
# Out:
#                Continent     Region             DevName  1980  1981  1982  \
# Country
# American Samoa   Oceania  Polynesia  Developing regions     0     1     0
# Samoa            Oceania  Polynesia  Developing regions     3     7     4
# Tonga            Oceania  Polynesia  Developing regions     2     4     7
# Tuvalu           Oceania  Polynesia  Developing regions     0     1     0
#
#                 1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  \
# Country                                 ...
# American Samoa     0     0     0     0  ...     0     1     0     0     0
# Samoa              1     3     0     3  ...     2     0     1     4     2
# Tonga              1     2     5     7  ...     2     0     1     0     5
# Tuvalu             0     1     0     0  ...     0     0     1     0     0
#
#                 2010  2011  2012  2013  Total
# Country
# American Samoa     0     0     0     0      6
# Samoa              5     3     2     0     78
# ...

# %%
print('data dimensions:', df_can.shape)
print(df_can.columns)
df_can.head(2)
# Out:
# data dimensions: (195, 38)
# Index(['Continent',    'Region',   'DevName',        1980,        1981,
#               1982,        1983,        1984,        1985,        1986,
#               1987,        1988,        1989,        1990,        1991,
#               1992,        1993,        1994,        1995,        1996,
#               1997,        1998,        1999,        2000,        2001,
#               2002,        2003,        2004,        2005,        2006,
#               2007,        2008,        2009,        2010,        2011,
#               2012,        2013,     'Total'],
#       dtype='object')
#             Continent           Region             DevName  1980  1981  1982  \
# Country
# Afghanistan      Asia    Southern Asia  Developing regions    16    39    39
# Albania        Europe  Southern Europe   Developed regions     1     0     0
#
#              1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  \
# Country                              ...
# ...
